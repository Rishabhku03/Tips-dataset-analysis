# %% [markdown]
# # Rishabh E20CSE203

# %% [markdown]
# ## Import Libraries

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
tip=pd.read_csv('tips.csv')
tip.shape
# Out:
# (244, 7)

# %% [markdown]
# ## First Five Row Of Dataset

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Last Five Row Of Dataset

# %%
tip.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# ## All Columns Of Tips Dataset

# %%
tip.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# ## Unique Values In Columns

# %%
tip.smoker.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
tip.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %% [markdown]
# ### Mon,Tue,wed(Data Missing)

# %%
tip.sex.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# ## Check Null Values

# %%
tip.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
tip.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# ## Describe Data

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## Count Value

# %%
x = tip.time.value_counts()
x
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %% [markdown]
# ## Count Value Percentage

# %%
y = tip.time.value_counts(normalize=True)
y
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %% [markdown]
# ## Plot Bar

# %%
x.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## When does people pay more tip ?

# %%
a=tip.groupby(['time'])['tip'].mean()
a
# Out:
# time
# Dinner    3.102670
# Lunch     2.728088
# Name: tip, dtype: float64

# %%
a.plot.bar()
# Out:
# <AxesSubplot:xlabel='time'>

# %% [markdown]
# ## Average Tips

# %%
b=tip.groupby(['smoker'])['tip'].mean()
b
# Out:
# smoker
# No     2.991854
# Yes    3.008710
# Name: tip, dtype: float64

# %%
b.plot.bar()
# Out:
# <AxesSubplot:xlabel='smoker'>

# %%
c=tip.groupby(['sex'])['tip'].mean()
c
# Out:
# sex
# Female    2.833448
# Male      3.089618
# Name: tip, dtype: float64

# %%
d=tip.groupby(['day'])['tip'].mean()
d
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
e=tip.groupby(['size'])['tip'].mean()
e
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %% [markdown]
# ## Analysing Data With Multiple Values

# %%
tip.groupby(['smoker','sex'])['tip'].mean()
# Out:
# smoker  sex
# No      Female    2.773519
#         Male      3.113402
# Yes     Female    2.931515
#         Male      3.051167
# Name: tip, dtype: float64

# %% [markdown]
# ## Visualize Data

# %%
sns.scatterplot(x = 'total_bill', y = 'tip' ,data=tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y = 'tip' ,data=tip, hue='sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = 'total_bill', y = 'tip' ,data=tip, hue='time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x = 'total_bill', y = 'tip' ,data=tip, col='sex', hue='time')

# %%
sns.displot(data=tip, x="total_bill",col='time', kde=True)

# %%
sns.pairplot(data=tip, hue='sex')
